# %% [markdown]
# # Matrix Faktorisierung

# %% [markdown]
# ## Imports

# %%
import pandas as pd
import numpy as np
from sklearn.decomposition import NMF

# %% [markdown]
# ## Datengrundlage

# %%
data = pd.DataFrame(np.random.randint(0,2,size=(1000,1000))*np.random.randint(0,4,size=(1000,1000)),columns=["Film {}".format(i+1) for i in range(1000)],index=["User {}".format(i+1) for i in range(1000)])

# %%
data
# Out:
#            Film 1  Film 2  Film 3  Film 4  Film 5  Film 6  Film 7  Film 8  \
# User 1          0       0       2       0       0       0       0       0
# User 2          0       3       3       0       0       0       2       1
# User 3          1       0       0       0       1       0       1       0
# User 4          0       0       3       3       3       0       0       3
# User 5          2       0       0       0       0       0       0       0
# ...           ...     ...     ...     ...     ...     ...     ...     ...
# User 996        3       2       0       0       3       2       0       0
# User 997        0       0       0       1       0       3       2       0
# User 998        0       0       0       2       0       3       2       0
# User 999        0       1       1       0       0       3       1       0
# User 1000       0       1       0       0       1       0       0       3
#
#            Film 9  Film 10  ...  Film 991  Film 992  Film 993  Film 994  \
# User 1          2        3  ...         0         3         0         0
# User 2          0        0  ...         0         3         0         0
# User 3          0        0  ...         0         3         1         3
# User 4          3        0  ...         0         0         1         1
# User 5          0        1  ...         0         0         1         2
# ...           ...      ...  ...       ...       ...       ...       ...
# User 996        2        0  ...         0         0         0         0
# User 997        0        2  ...         0         0         0         0
# User 998        2        2  ...         0         3         0         3
# User 999        0        0  ...         0         0         0         0
# User 1000       0        0  ...         3         3         0         3
#
#            Film 995  Film 996  Film 997  Film 998  Film 999  Film 1000
# User 1            1         2         2         0         0          0
# User 2            0         1         3         2         2          1
# User 3            0         0         0         0         0          3
# User 4            0         1         0         0         0          0
# User 5            1         0         3         0         0          1
# ...             ...       ...       ...       ...       ...        ...
# User 996          0         0         0         0         0          0
# User 997          2         1         2         0         0          2
# User 998          0         0         3         0         3          1
# User 999          0         0         0         0         3          3
# User 1000         2         2         0         1         1          1
#
# [1000 rows x 1000 columns]

# %% [markdown]
# ## Matrix Faktorisierung

# %%
model = NMF(n_components=5,max_iter=1000)
user_vectors = model.fit_transform(data)
item_vectors = model.components_
# Out:
# /usr/local/lib/python3.8/site-packages/sklearn/decomposition/_nmf.py:312: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   warnings.warn(("The 'init' value, when 'init=None' and "
# /usr/local/lib/python3.8/site-packages/sklearn/decomposition/_nmf.py:1090: ConvergenceWarning: Maximum number of iterations 1000 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"

# %%
np.dot(user_vectors,item_vectors)
# Out:
# array([[0.52675943, 0.41506399, 0.81352605, ..., 1.07205302, 0.77308811,
#         1.16202332],
#        [0.74743461, 0.50078191, 0.86205748, ..., 0.95256285, 0.78859856,
#         1.04093572],
#        [0.71409574, 0.57601936, 0.79878836, ..., 0.75244166, 0.64945108,
#         0.78536256],
#        ...,
#        [1.11818756, 0.93606514, 0.78449527, ..., 0.5703483 , 0.8063653 ,
#         0.61575711],
#        [0.82088286, 0.68287195, 0.78318653, ..., 0.73104049, 0.76732413,
#         0.79631408],
#        [0.79036206, 1.10248385, 0.61015219, ..., 0.73596221, 0.54393475,
#         0.62427302]])

# %%
item_vectors
# Out:
# array([[0.56045355, 0.58455449, 0.37278054, ..., 0.33143713, 0.34842434,
#         0.14558151],
#        [0.1551203 , 0.18951503, 0.44775804, ..., 0.7030384 , 0.38316897,
#         0.71693176],
#        [0.54995282, 0.24976125, 0.94405335, ..., 0.4085805 , 0.46739151,
#         0.3190665 ],
#        [0.11094136, 0.70291006, 0.08368863, ..., 0.36116034, 0.        ,
#         0.17500357],
#        [0.64963768, 0.15155773, 0.04105213, ..., 0.12634313, 0.53537729,
#         0.63519183]])
