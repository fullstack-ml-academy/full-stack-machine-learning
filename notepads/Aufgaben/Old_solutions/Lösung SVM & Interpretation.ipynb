# %% [markdown]
# ## Imports

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler

# %% [markdown]
# ## Datengrundlage

# %%
data = pd.read_csv("/data/mpg.csv")
x = data.drop(["mpg"],axis=1)
y = data["mpg"]

scaler = MinMaxScaler()
x = scaler.fit_transform(x)

x_train, x_test, y_train, y_test = train_test_split(x,y)
x_train = pd.DataFrame(x_train,columns=data.drop(["mpg"],axis=1).columns)
x_test = pd.DataFrame(x_train,columns=data.drop(["mpg"],axis=1).columns)

# %% [markdown]
# ## Modell Training

# %%
linreg = LinearRegression()
linreg.fit(x_train, y_train)

svr = SVR()
svr.fit(x_train, y_train)

dtr = DecisionTreeRegressor()
dtr.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor()

# %% [markdown]
# ## Interpretation

# %%
plt.bar(x_train.columns,linreg.coef_)
plt.xticks(rotation=45)
plt.show()

# %%
plt.bar(x_train.columns,dtr.feature_importances_)
plt.xticks(rotation=45)
plt.show()
