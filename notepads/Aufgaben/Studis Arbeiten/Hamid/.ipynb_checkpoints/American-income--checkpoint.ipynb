# %%
import numpy as np
import pandas as pd 
from sklearn.tree import DecisionTreeClassifier
df = pd.read_excel(r'file:///C:\Users\admin\Desktop\DIgethic\Nuability\Census-Datensatz%20-%20Copy.xlsx')

# %%
df.head()
# Out:
#    age          workclass  fnlwgt   education  education-num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
#
#         marital-status          occupation    relationship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    capital-gain  capital-loss  hours-per-week  native-country  income
# 0          2174             0              40   United-States   <=50K
# ...

# %%
pip install openpyxl
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
df1 = df.copy()

# %%
df1.describe()
# Out:
#                 age        fnlwgt  education-num  capital-gain  capital-loss  \
# count  32561.000000  3.256100e+04   32561.000000  32561.000000  32561.000000
# mean      38.581647  1.897784e+05      10.080679   1077.648844     87.303830
# std       13.640433  1.055500e+05       2.572720   7385.292085    402.960219
# min       17.000000  1.228500e+04       1.000000      0.000000      0.000000
# 25%       28.000000  1.178270e+05       9.000000      0.000000      0.000000
# 50%       37.000000  1.783560e+05      10.000000      0.000000      0.000000
# 75%       48.000000  2.370510e+05      12.000000      0.000000      0.000000
# max       90.000000  1.484705e+06      16.000000  99999.000000   4356.000000
#
#        hours-per-week
# count    32561.000000
# mean        40.437456
# std         12.347429
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000

# %%
df1.pop('occupation')
df1.pop('fnlwgt')
df1.pop('workclass')
df1.pop('education')
df1.pop('marital-status')
df1.pop('relationship')
df1.pop('native-country')
# Out:
# 0         United-States
# 1         United-States
# 2         United-States
# 3         United-States
# 4                  Cuba
#               ...
# 32556     United-States
# 32557     United-States
# 32558     United-States
# 32559     United-States
# 32560     United-States
# Name: native-country, Length: 32561, dtype: object

# %%
from pandas.plotting import scatter_matrix  
from sklearn.impute import SimpleImputer
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %%
# Numerische Werte:

# SEX: Male: 1, Female: 0
df1["sex"] = df1["sex"].replace({' Male': 1, ' Female': 0})

# RACE: Asian-Pac-Islander: 4, White: 3, Black: 2, Amer-Indian-Eskimo: 1, Other: 0
df1["race"] = df1["race"].replace({' White': 3, ' Black': 2, ' Asian-Pac-Islander': 4, ' Amer-Indian-Eskimo':1, ' Other': 0})

# TARGET: >50K: 1, <=50K: 0 
df1["income"] = df1["income"].replace({' >50K': 1, ' <=50K': 0})

# %%
df1.describe()
# Out:
#                 age  education-num          race           sex  capital-gain  \
# count  32561.000000   32561.000000  32561.000000  32561.000000  32561.000000
# mean      38.581647      10.080679      2.891895      0.669205   1077.648844
# std       13.640433       2.572720      0.478836      0.470506   7385.292085
# min       17.000000       1.000000      0.000000      0.000000      0.000000
# 25%       28.000000       9.000000      3.000000      0.000000      0.000000
# 50%       37.000000      10.000000      3.000000      1.000000      0.000000
# 75%       48.000000      12.000000      3.000000      1.000000      0.000000
# max       90.000000      16.000000      4.000000      1.000000  99999.000000
#
#        capital-loss  hours-per-week        income
# count  32561.000000    32561.000000  32561.000000
# mean      87.303830       40.437456      0.240810
# std      402.960219       12.347429      0.427581
# min        0.000000        1.000000      0.000000
# ...

# %%
#train_set, test_set = train_test_split(df1, test_size=0.3, random_state=2)
#train_set.shape
#train_set.head()
#from sklearn.model_selection import DecisionTreeClassifier 
from sklearn import tree
#X = df1.drop(['income'],axis=1)

y = df1['income']
df1.pop('income')
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

# %%
print(f"X_train:{X_train.shape}")
print("y_train:{}".format(y_train.shape))
print(f"X_test:{X_test.shape}")
print("y_test:{}".format(y_test.shape))
# Out:
# X_train:(22792, 7)
# y_train:(22792,)
# X_test:(9769, 7)
# y_test:(9769,)

# %%
df1.describe()
# Out:
#                 age  education-num          race           sex  capital-gain  \
# count  32561.000000   32561.000000  32561.000000  32561.000000  32561.000000
# mean      38.581647      10.080679      2.891895      0.669205   1077.648844
# std       13.640433       2.572720      0.478836      0.470506   7385.292085
# min       17.000000       1.000000      0.000000      0.000000      0.000000
# 25%       28.000000       9.000000      3.000000      0.000000      0.000000
# 50%       37.000000      10.000000      3.000000      1.000000      0.000000
# 75%       48.000000      12.000000      3.000000      1.000000      0.000000
# max       90.000000      16.000000      4.000000      1.000000  99999.000000
#
#        capital-loss  hours-per-week
# count  32561.000000    32561.000000
# mean      87.303830       40.437456
# std      402.960219       12.347429
# min        0.000000        1.000000
# 25%        0.000000       40.000000
# 50%        0.000000       40.000000
# ...

# %%
df1.mean()
# Out:
# age                 38.581647
# education-num       10.080679
# race                 2.891895
# sex                  0.669205
# capital-gain      1077.648844
# capital-loss        87.303830
# hours-per-week      40.437456
# dtype: float64

# %%
import numpy as np
def compare_mean(dataFrame,features):
    return np.mean(dataFrame[features])
     
        
for features in df1.columns: 
    print(f"features:{features}, mean_test: {compare_mean(X_test, features)}, mean_train: {compare_mean(X_train, features)}")
# Out:
# features:age, mean_test: 38.50629542430136, mean_train: 38.61394348894349
# features:education-num, mean_test: 10.123758828948715, mean_train: 10.062214812214812
# features:race, mean_test: 2.88791073804893, mean_train: 2.8936030186030184
# features:sex, mean_test: 0.66854335141775, mean_train: 0.6694892944892945
# features:capital-gain, mean_test: 1189.752789435971, mean_train: 1029.599376974377
# features:capital-loss, mean_test: 81.16378339645819, mean_train: 89.93554756054756
# features:hours-per-week, mean_test: 40.44958542327772, mean_train: 40.432256932256934

# %%
plt.figure(figsize=(6,4))
sns.heatmap(df1.corr(),cmap='coolwarm',annot=True)
# Out:
# <AxesSubplot:>

# %%
df1
# Out:
#        age  education-num  race  sex  capital-gain  capital-loss  \
# 0       39             13     3    1          2174             0
# 1       50             13     3    1             0             0
# 2       38              9     3    1             0             0
# 3       53              7     2    1             0             0
# 4       28             13     2    0             0             0
# ...    ...            ...   ...  ...           ...           ...
# 32556   27             12     3    0             0             0
# 32557   40              9     3    1             0             0
# 32558   58              9     3    0             0             0
# 32559   22              9     3    1             0             0
# 32560   52              9     3    0         15024             0
#
#        hours-per-week  income
# 0                  40       0
# 1                  13       0
# 2                  40       0
# 3                  40       0
# ...

# %%
corr_matrix["age"]
# Out:
# age               1.000000
# education-num     0.036527
# race              0.031582
# sex               0.088832
# capital-gain      0.077674
# capital-loss      0.057775
# hours-per-week    0.068756
# income            0.234037
# Name: age, dtype: float64

# %%
corr_matrix["education-num"]
# Out:
# age               0.036527
# education-num     1.000000
# race              0.106130
# sex               0.012280
# capital-gain      0.122630
# capital-loss      0.079923
# hours-per-week    0.148123
# income            0.335154
# Name: education-num, dtype: float64

# %%
features =["age","education-num","capital-gain","capital-loss","hours-per-week","income"]
scatter_matrix(df1[features],figsize=(10,7))
plt.show()

# %%
sns.pairplot(df1[features])

# %%
df1.plot(kind="scatter",x="age", y="hours-per-week", figsize=(9,6))
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# <AxesSubplot:xlabel='age', ylabel='hours-per-week'>

# %%
    df1.plot(kind="scatter",x="education-num", y="hours-per-week", figsize=(5,4),alpha=0.4)
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# <AxesSubplot:xlabel='education-num', ylabel='hours-per-week'>

# %%
df1.plot(kind="scatter",x="education-num", y="capital-gain", figsize=(5,4),alpha=0.4)
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# <AxesSubplot:xlabel='education-num', ylabel='capital-gain'>
